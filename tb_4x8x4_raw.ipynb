# %%
from __future__ import division
import numpy as np
import matplotlib.pyplot as plt

intp = 10  #tomar uno de cada cien valores, para graficar rapido

# Load data from the .txt file
#ssh -Y cic@148.204.66.123
#ssh -Y alex@148.204.66.53

#source ~/miniconda3/bin/activate
#python3 tb_4x8x4_proc.py
#scp alex@148.204.66.53:'/home/cic/Desktop/EDA/SNN_IPN/sim_results/*.pdf' .
#scp cic@148.204.66.123:'/home/cic/Desktop/EDA/SNN_IPN/sim_results/*.pdf' .

#scp alex@148.204.66.53:/home/alex/.xschem/simulations/data.raw .
#scp alex@148.204.66.53:/home/alex/Desktop/EDA/SNN_IPN/sim_results/tb_4x8x4_data.txt . 
#scp cic@148.204.66.123:/home/cic/Desktop/EDA/SNN_IPN/sim_results/tb_4x8x4_data.txt  .

BSIZE_SP = 512 # Max size of a line of data; we don't want to read the
               # whole file to find a line, in case file does not have
               # expected structure.

MDATA_LIST = [b'title', b'date', b'plotname', b'flags', b'no. variables',
              b'no. points', b'dimensions', b'command', b'option']

def rawread(fname: str):
    """Read ngspice binary raw files. Return tuple of the data, and the
    plot metadata. The dtype of the data contains field names. This is
    not very robust yet, and only supports ngspice.
    
    >>> darr, mdata = rawread('test.py')
    >>> darr.dtype.names
    >>> plot(np.real(darr['frequency']), np.abs(darr['v(out)']))
    """
    # Example header of raw file
    # Title: rc band pass example circuit
    # Date: Sun Feb 21 11:29:14  2016
    # Plotname: AC Analysis
    # Flags: complex
    # No. Variables: 3
    # No. Points: 41
    # Variables:
    #         0       frequency       frequency       grid=3
    #         1       v(out)  voltage
    #         2       v(in)   voltage
    # Binary:
    fp = open(fname, 'rb')
    arrs = []
    plots = []
    plot = {}
    while (True):
        try:
            # mdata = fp.readline(BSIZE_SP).split(b':', maxsplit=1)
            mdata = fp.readline().split(b':', maxsplit=1)
        except:
            raise
        if len(mdata) == 2:
            if mdata[0].lower() in MDATA_LIST:
                plot[mdata[0].lower()] = mdata[1].strip()
            if mdata[0].lower() == b'variables':
                nvars = int(plot[b'no. variables'])
                npoints = int(plot[b'no. points'])
                plot['varnames'] = []
                plot['varunits'] = []
                for varn in range(nvars):
                    # varspec = (fp.readline(BSIZE_SP).strip().decode('ascii').split())
                    varspec = (fp.readline().strip().decode('ascii').split())
                    assert(varn == int(varspec[0]))
                    plot['varnames'].append(varspec[1])
                    plot['varunits'].append(varspec[2])
            if mdata[0].lower() == b'binary':
                rowdtype = np.dtype({'names': plot['varnames'],
                                     'formats': [np.complex_ if b'complex'
                                                 in plot[b'flags']
                                                 else np.float64]*nvars})
                # We should have all the metadata by now
                arrs.append(np.fromfile(fp, dtype=rowdtype, count=npoints))
                plots.append(plot)
                plot = {} # reset the plot dict
                fp.readline() # Read to the end of line
        else:
            break
    return (arrs[0], plots)

data, dicc = rawread("data.raw")

# %%
dicc
# Out:
# [{b'title': b'** sch_path: /foss/designs/snn-mwip/tb_net_mwip.sch',
#   b'date': b'Mon Apr 20 20:38:59  2026',
#   b'command': b'ngspice-45.2, Build Sun Dec 21 19:31:43 UTC 2025',
#   b'plotname': b'Transient Analysis',
#   b'flags': b'real',
#   b'no. variables': b'517',
#   b'no. points': b'20008',
#   'varnames': ['time',
#    'v(dth)',
#    'v(dth_nom)',
#    'v(dx)',
#    'v(dx_nom)',
#    'v(e_th)',
#    'v(e_x)',
#    'v(tau)',
#    'v(tau_nom)',
#    'v(th)',
#    'v(th_nom)',
#    'v(th_ref)',
#    'i(v.x1.x1.x5.vineg1)',
#    'i(v.x1.x1.x5.vineg2)',
#    'i(v.x1.x1.x5.vipos)',
#    'i(v.x1.x1.x5.vipos1)',
#    'i(v.x1.x2.x5.vineg1)',
#    'i(v.x1.x2.x5.vineg2)',
#    'i(v.x1.x2.x5.vipos)',
#    'i(v.x1.x2.x5.vipos1)',
#    'i(v.x1.x3.x5.vineg1)',
#    'i(v.x1.x3.x5.vineg2)',
#    'i(v.x1.x3.x5.vipos)',
#    'i(v.x1.x3.x5.vipos1)',
#    'i(v.x1.x4.x5.vineg1)',
#    'i(v.x1.x4.x5.vineg2)',
#    'i(v.x1.x4.x5.vipos)',
#    'i(v.x1.x4.x5.vipos1)',
#    'i(v.x1.x5.xno_stdp1.vmr)',
#    'i(v.x1.x5.xno_stdp2.vmr)',
#    'i(v.x1.x5.xno_stdp3.vmr)',
#    'i(v.x1.x5.xno_stdp4.vmr)',
#    'i(v.x1.x5.xno_stdp5.vmr)',
#    'i(v.x1.x5.xno_stdp6.vmr)',
#    'i(v.x1.x5.xno_stdp7.vmr)',
#    'i(v.x1.x5.xno_stdp8.vmr)',
#    'i(v.x1.x5.xno_stdp9.vmr)',
#    'i(v.x1.x5.xno_stdp10.vmr)',
#    'i(v.x1.x5.xno_stdp11.vmr)',
#    'i(v.x1.x5.xno_stdp12.vmr)',
#    'i(v.x1.x5.xno_stdp13.vmr)',
#    'i(v.x1.x5.xno_stdp14.vmr)',
#    'i(v.x1.x5.xno_stdp15.vmr)',
#    'i(v.x1.x5.xno_stdp16.vmr)',
#    'i(v.x1.x5.xno_stdp17.vmr)',
#    'i(v.x1.x5.xno_stdp18.vmr)',
#    'i(v.x1.x5.xno_stdp19.vmr)',
#    'i(v.x1.x5.xno_stdp20.vmr)',
#    'i(v.x1.x5.xno_stdp21.vmr)',
#    'i(v.x1.x5.xno_stdp22.vmr)',
#    'i(v.x1.x5.xno_stdp23.vmr)',
#    'i(v.x1.x5.xno_stdp24.vmr)',
#    'i(v.x1.x5.xno_stdp25.vmr)',
#    'i(v.x1.x5.xno_stdp26.vmr)',
#    'i(v.x1.x5.xno_stdp27.vmr)',
#    'i(v.x1.x5.xno_stdp28.vmr)',
#    'i(v.x1.x5.xno_stdp29.vmr)',
#    'i(v.x1.x5.xno_stdp30.vmr)',
#    'i(v.x1.x5.xno_stdp31.vmr)',
#    'i(v.x1.x5.xno_stdp32.vmr)',
#    'i(v.x1.x5.xno_stdp33.vmr)',
#    'i(v.x1.x5.xno_stdp34.vmr)',
#    'i(v.x1.x5.xno_stdp35.vmr)',
#    'i(v.x1.x5.xno_stdp36.vmr)',
#    'i(v.x1.x5.xno_stdp37.vmr)',
#    'i(v.x1.x5.xno_stdp38.vmr)',
#    'i(v.x1.x5.xno_stdp39.vmr)',
#    'i(v.x1.x5.xno_stdp40.vmr)',
#    'i(v.x1.x5.xno_stdp41.vmr)',
#    'i(v.x1.x5.xno_stdp42.vmr)',
#    'i(v.x1.x5.xno_stdp43.vmr)',
#    'i(v.x1.x5.xno_stdp44.vmr)',
#    'i(v.x1.x5.xno_stdp45.vmr)',
#    'i(v.x1.x5.xno_stdp46.vmr)',
#    'i(v.x1.x5.xno_stdp47.vmr)',
#    'i(v.x1.x5.xno_stdp48.vmr)',
#    'i(v.x1.x5.xno_stdp49.vmr)',
#    'i(v.x1.x5.xno_stdp50.vmr)',
#    'i(v.x1.x5.xno_stdp51.vmr)',
#    'i(v.x1.x5.xno_stdp52.vmr)',
#    'i(v.x1.x5.xno_stdp53.vmr)',
#    'i(v.x1.x5.xno_stdp54.vmr)',
#    'i(v.x1.x5.xno_stdp55.vmr)',
#    'i(v.x1.x5.xno_stdp56.vmr)',
#    'i(v.x1.x5.xno_stdp57.vmr)',
#    'i(v.x1.x5.xno_stdp58.vmr)',
#    'i(v.x1.x5.xno_stdp59.vmr)',
#    'i(v.x1.x5.xno_stdp60.vmr)',
#    'i(v.x1.x5.xno_stdp61.vmr)',
#    'i(v.x1.x5.xno_stdp62.vmr)',
#    'i(v.x1.x5.xno_stdp63.vmr)',
#    'i(v.x1.x5.xno_stdp64.vmr)',
#    'i(v.x1.x5.xno_stdp65.vmr)',
#    'i(v.x1.x5.xno_stdp66.vmr)',
#    'i(v.x1.x5.xno_stdp67.vmr)',
#    'i(v.x1.x5.xno_stdp68.vmr)',
#    'i(v.x1.x5.xno_stdp69.vmr)',
#    'i(v.x1.x5.xno_stdp70.vmr)',
#    'i(v.x1.x5.xno_stdp71.vmr)',
#    'i(v.x1.x5.xno_stdp72.vmr)',
#    'i(v.x1.x5.xno_stdp73.vmr)',
#    'i(v.x1.x5.xno_stdp74.vmr)',
#    'i(v.x1.x5.xno_stdp75.vmr)',
#    'i(v.x1.x5.xno_stdp76.vmr)',
#    'i(v.x1.x5.xno_stdp77.vmr)',
#    'i(v.x1.x5.xno_stdp78.vmr)',
#    'i(v.x1.x5.xno_stdp79.vmr)',
#    'i(v.x1.x5.xno_stdp80.vmr)',
#    'i(v.x1.x5.xno_stdp81.vmr)',
#    'i(v.x1.x5.xno_stdp82.vmr)',
#    'i(v.x1.x5.xno_stdp83.vmr)',
#    'i(v.x1.x5.xno_stdp84.vmr)',
#    'i(v.x1.x5.xno_stdp85.vmr)',
#    'i(v.x1.x5.xno_stdp86.vmr)',
#    'i(v.x1.x5.xno_stdp87.vmr)',
#    'i(v.x1.x5.xno_stdp88.vmr)',
#    'i(v.x1.x5.xno_stdp89.vmr)',
#    'i(v.x1.x5.xno_stdp90.vmr)',
#    'i(v.x1.x5.xno_stdp91.vmr)',
#    'i(v.x1.x5.xno_stdp92.vmr)',
#    'i(v.x1.x5.xno_stdp93.vmr)',
#    'i(v.x1.x5.xno_stdp94.vmr)',
#    'i(v.x1.x5.xno_stdp95.vmr)',
#    'i(v.x1.x5.xno_stdp96.vmr)',
#    'i(v.x1.x5.xno_stdp97.vmr)',
#    'i(v.x1.x5.xno_stdp98.vmr)',
#    'i(v.x1.x5.xno_stdp99.vmr)',
#    'i(v.x1.x5.xno_stdp100.vmr)',
#    'i(v.x1.x5.xno_stdp101.vmr)',
#    'i(v.x1.x5.xno_stdp102.vmr)',
#    'i(v.x1.x5.xno_stdp103.vmr)',
#    'i(v.x1.x5.xno_stdp104.vmr)',
#    'i(v.x1.x5.xno_stdp105.vmr)',
#    'i(v.x1.x5.xno_stdp106.vmr)',
#    'i(v.x1.x5.xno_stdp107.vmr)',
#    'i(v.x1.x5.xno_stdp108.vmr)',
#    'i(v.x1.x5.xno_stdp109.vmr)',
#    'i(v.x1.x5.xno_stdp110.vmr)',
#    'i(v.x1.x5.xno_stdp111.vmr)',
#    'i(v.x1.x5.xno_stdp112.vmr)',
#    'i(v.x1.x5.xno_stdp113.vmr)',
#    'i(v.x1.x5.xno_stdp114.vmr)',
#    'i(v.x1.x5.xno_stdp115.vmr)',
#    'i(v.x1.x5.xno_stdp116.vmr)',
#    'i(v.x1.x5.xno_stdp117.vmr)',
#    'i(v.x1.x5.xno_stdp118.vmr)',
#    'i(v.x1.x5.xno_stdp119.vmr)',
#    'i(v.x1.x5.xno_stdp120.vmr)',
#    'i(v.x1.x5.xno_stdp121.vmr)',
#    'i(v.x1.x5.xno_stdp122.vmr)',
#    'i(v.x1.x5.xno_stdp123.vmr)',
#    'i(v.x1.x5.xno_stdp124.vmr)',
#    'i(v.x1.x5.xno_stdp125.vmr)',
#    'i(v.x1.x5.xno_stdp126.vmr)',
#    'i(v.x1.x5.xno_stdp127.vmr)',
#    'i(v.x1.x5.xno_stdp128.vmr)',
#    'i(v.x1.x7.xstdp1.vmr)',
#    'i(v.x1.x7.xstdp2.vmr)',
#    'i(v.x1.x7.xstdp3.vmr)',
#    'i(v.x1.x7.xstdp4.vmr)',
#    'i(v.x1.x7.xstdp5.vmr)',
#    'i(v.x1.x7.xstdp6.vmr)',
#    'i(v.x1.x7.xstdp7.vmr)',
#    'i(v.x1.x7.xstdp8.vmr)',
#    'i(v.x1.x7.xstdp9.vmr)',
#    'i(v.x1.x7.xstdp10.vmr)',
#    'i(v.x1.x7.xstdp11.vmr)',
#    'i(v.x1.x7.xstdp12.vmr)',
#    'i(v.x1.x7.xstdp13.vmr)',
#    'i(v.x1.x7.xstdp14.vmr)',
#    'i(v.x1.x7.xstdp15.vmr)',
#    'i(v.x1.x7.xstdp16.vmr)',
#    'i(v.x1.x7.xstdp17.vmr)',
#    'i(v.x1.x7.xstdp18.vmr)',
#    'i(v.x1.x7.xstdp19.vmr)',
#    'i(v.x1.x7.xstdp20.vmr)',
#    'i(v.x1.x7.xstdp21.vmr)',
#    'i(v.x1.x7.xstdp22.vmr)',
#    'i(v.x1.x7.xstdp23.vmr)',
#    'i(v.x1.x7.xstdp24.vmr)',
#    'i(v.x1.x7.xstdp25.vmr)',
#    'i(v.x1.x7.xstdp26.vmr)',
#    'i(v.x1.x7.xstdp27.vmr)',
#    'i(v.x1.x7.xstdp28.vmr)',
#    'i(v.x1.x7.xstdp29.vmr)',
#    'i(v.x1.x7.xstdp30.vmr)',
#    'i(v.x1.x7.xstdp31.vmr)',
#    'i(v.x1.x7.xstdp32.vmr)',
#    'v(x)',
#    'v(x1.hj1)',
#    'v(x1.hj2)',
#    'v(x1.hj3)',
#    'v(x1.hj4)',
#    'v(x1.hk1)',
#    'v(x1.hl1)',
#    'v(x1.x5.xno_stdp1.be)',
#    'v(x1.x5.xno_stdp1.te)',
#    'v(x1.x5.xno_stdp2.be)',
#    'v(x1.x5.xno_stdp2.te)',
#    'v(x1.x5.xno_stdp3.be)',
#    'v(x1.x5.xno_stdp3.te)',
#    'v(x1.x5.xno_stdp4.be)',
#    'v(x1.x5.xno_stdp4.te)',
#    'v(x1.x5.xno_stdp5.be)',
#    'v(x1.x5.xno_stdp5.te)',
#    'v(x1.x5.xno_stdp6.be)',
#    'v(x1.x5.xno_stdp6.te)',
#    'v(x1.x5.xno_stdp7.be)',
#    'v(x1.x5.xno_stdp7.te)',
#    'v(x1.x5.xno_stdp8.be)',
#    'v(x1.x5.xno_stdp8.te)',
#    'v(x1.x5.xno_stdp9.be)',
#    'v(x1.x5.xno_stdp9.te)',
#    'v(x1.x5.xno_stdp10.be)',
#    'v(x1.x5.xno_stdp10.te)',
#    'v(x1.x5.xno_stdp11.be)',
#    'v(x1.x5.xno_stdp11.te)',
#    'v(x1.x5.xno_stdp12.be)',
#    'v(x1.x5.xno_stdp12.te)',
#    'v(x1.x5.xno_stdp13.be)',
#    'v(x1.x5.xno_stdp13.te)',
#    'v(x1.x5.xno_stdp14.be)',
#    'v(x1.x5.xno_stdp14.te)',
#    'v(x1.x5.xno_stdp15.be)',
#    'v(x1.x5.xno_stdp15.te)',
#    'v(x1.x5.xno_stdp16.be)',
#    'v(x1.x5.xno_stdp16.te)',
#    'v(x1.x5.xno_stdp17.be)',
#    'v(x1.x5.xno_stdp17.te)',
#    'v(x1.x5.xno_stdp18.be)',
#    'v(x1.x5.xno_stdp18.te)',
#    'v(x1.x5.xno_stdp19.be)',
#    'v(x1.x5.xno_stdp19.te)',
#    'v(x1.x5.xno_stdp20.be)',
#    'v(x1.x5.xno_stdp20.te)',
#    'v(x1.x5.xno_stdp21.be)',
#    'v(x1.x5.xno_stdp21.te)',
#    'v(x1.x5.xno_stdp22.be)',
#    'v(x1.x5.xno_stdp22.te)',
#    'v(x1.x5.xno_stdp23.be)',
#    'v(x1.x5.xno_stdp23.te)',
#    'v(x1.x5.xno_stdp24.be)',
#    'v(x1.x5.xno_stdp24.te)',
#    'v(x1.x5.xno_stdp25.be)',
#    'v(x1.x5.xno_stdp25.te)',
#    'v(x1.x5.xno_stdp26.be)',
#    'v(x1.x5.xno_stdp26.te)',
#    'v(x1.x5.xno_stdp27.be)',
#    'v(x1.x5.xno_stdp27.te)',
#    'v(x1.x5.xno_stdp28.be)',
#    'v(x1.x5.xno_stdp28.te)',
#    'v(x1.x5.xno_stdp29.be)',
#    'v(x1.x5.xno_stdp29.te)',
#    'v(x1.x5.xno_stdp30.be)',
#    'v(x1.x5.xno_stdp30.te)',
#    'v(x1.x5.xno_stdp31.be)',
#    'v(x1.x5.xno_stdp31.te)',
#    'v(x1.x5.xno_stdp32.be)',
#    'v(x1.x5.xno_stdp32.te)',
#    'v(x1.x5.xno_stdp33.be)',
#    'v(x1.x5.xno_stdp33.te)',
#    'v(x1.x5.xno_stdp34.be)',
#    'v(x1.x5.xno_stdp34.te)',
#    'v(x1.x5.xno_stdp35.be)',
#    'v(x1.x5.xno_stdp35.te)',
#    'v(x1.x5.xno_stdp36.be)',
#    'v(x1.x5.xno_stdp36.te)',
#    'v(x1.x5.xno_stdp37.be)',
#    'v(x1.x5.xno_stdp37.te)',
#    'v(x1.x5.xno_stdp38.be)',
#    'v(x1.x5.xno_stdp38.te)',
#    'v(x1.x5.xno_stdp39.be)',
#    'v(x1.x5.xno_stdp39.te)',
#    'v(x1.x5.xno_stdp40.be)',
#    'v(x1.x5.xno_stdp40.te)',
#    'v(x1.x5.xno_stdp41.be)',
#    'v(x1.x5.xno_stdp41.te)',
#    'v(x1.x5.xno_stdp42.be)',
#    'v(x1.x5.xno_stdp42.te)',
#    'v(x1.x5.xno_stdp43.be)',
#    'v(x1.x5.xno_stdp43.te)',
#    'v(x1.x5.xno_stdp44.be)',
#    'v(x1.x5.xno_stdp44.te)',
#    'v(x1.x5.xno_stdp45.be)',
#    'v(x1.x5.xno_stdp45.te)',
#    'v(x1.x5.xno_stdp46.be)',
#    'v(x1.x5.xno_stdp46.te)',
#    'v(x1.x5.xno_stdp47.be)',
#    'v(x1.x5.xno_stdp47.te)',
#    'v(x1.x5.xno_stdp48.be)',
#    'v(x1.x5.xno_stdp48.te)',
#    'v(x1.x5.xno_stdp49.be)',
#    'v(x1.x5.xno_stdp49.te)',
#    'v(x1.x5.xno_stdp50.be)',
#    'v(x1.x5.xno_stdp50.te)',
#    'v(x1.x5.xno_stdp51.be)',
#    'v(x1.x5.xno_stdp51.te)',
#    'v(x1.x5.xno_stdp52.be)',
#    'v(x1.x5.xno_stdp52.te)',
#    'v(x1.x5.xno_stdp53.be)',
#    'v(x1.x5.xno_stdp53.te)',
#    'v(x1.x5.xno_stdp54.be)',
#    'v(x1.x5.xno_stdp54.te)',
#    'v(x1.x5.xno_stdp55.be)',
#    'v(x1.x5.xno_stdp55.te)',
#    'v(x1.x5.xno_stdp56.be)',
#    'v(x1.x5.xno_stdp56.te)',
#    'v(x1.x5.xno_stdp57.be)',
#    'v(x1.x5.xno_stdp57.te)',
#    'v(x1.x5.xno_stdp58.be)',
#    'v(x1.x5.xno_stdp58.te)',
#    'v(x1.x5.xno_stdp59.be)',
#    'v(x1.x5.xno_stdp59.te)',
#    'v(x1.x5.xno_stdp60.be)',
#    'v(x1.x5.xno_stdp60.te)',
#    'v(x1.x5.xno_stdp61.be)',
#    'v(x1.x5.xno_stdp61.te)',
#    'v(x1.x5.xno_stdp62.be)',
#    'v(x1.x5.xno_stdp62.te)',
#    'v(x1.x5.xno_stdp63.be)',
#    'v(x1.x5.xno_stdp63.te)',
#    'v(x1.x5.xno_stdp64.be)',
#    'v(x1.x5.xno_stdp64.te)',
#    'v(x1.x5.xno_stdp65.be)',
#    'v(x1.x5.xno_stdp65.te)',
#    'v(x1.x5.xno_stdp66.be)',
#    'v(x1.x5.xno_stdp66.te)',
#    'v(x1.x5.xno_stdp67.be)',
#    'v(x1.x5.xno_stdp67.te)',
#    'v(x1.x5.xno_stdp68.be)',
#    'v(x1.x5.xno_stdp68.te)',
#    'v(x1.x5.xno_stdp69.be)',
#    'v(x1.x5.xno_stdp69.te)',
#    'v(x1.x5.xno_stdp70.be)',
#    'v(x1.x5.xno_stdp70.te)',
#    'v(x1.x5.xno_stdp71.be)',
#    'v(x1.x5.xno_stdp71.te)',
#    'v(x1.x5.xno_stdp72.be)',
#    'v(x1.x5.xno_stdp72.te)',
#    'v(x1.x5.xno_stdp73.be)',
#    'v(x1.x5.xno_stdp73.te)',
#    'v(x1.x5.xno_stdp74.be)',
#    'v(x1.x5.xno_stdp74.te)',
#    'v(x1.x5.xno_stdp75.be)',
#    'v(x1.x5.xno_stdp75.te)',
#    'v(x1.x5.xno_stdp76.be)',
#    'v(x1.x5.xno_stdp76.te)',
#    'v(x1.x5.xno_stdp77.be)',
#    'v(x1.x5.xno_stdp77.te)',
#    'v(x1.x5.xno_stdp78.be)',
#    'v(x1.x5.xno_stdp78.te)',
#    'v(x1.x5.xno_stdp79.be)',
#    'v(x1.x5.xno_stdp79.te)',
#    'v(x1.x5.xno_stdp80.be)',
#    'v(x1.x5.xno_stdp80.te)',
#    'v(x1.x5.xno_stdp81.be)',
#    'v(x1.x5.xno_stdp81.te)',
#    'v(x1.x5.xno_stdp82.be)',
#    'v(x1.x5.xno_stdp82.te)',
#    'v(x1.x5.xno_stdp83.be)',
#    'v(x1.x5.xno_stdp83.te)',
#    'v(x1.x5.xno_stdp84.be)',
#    'v(x1.x5.xno_stdp84.te)',
#    'v(x1.x5.xno_stdp85.be)',
#    'v(x1.x5.xno_stdp85.te)',
#    'v(x1.x5.xno_stdp86.be)',
#    'v(x1.x5.xno_stdp86.te)',
#    'v(x1.x5.xno_stdp87.be)',
#    'v(x1.x5.xno_stdp87.te)',
#    'v(x1.x5.xno_stdp88.be)',
#    'v(x1.x5.xno_stdp88.te)',
#    'v(x1.x5.xno_stdp89.be)',
#    'v(x1.x5.xno_stdp89.te)',
#    'v(x1.x5.xno_stdp90.be)',
#    'v(x1.x5.xno_stdp90.te)',
#    'v(x1.x5.xno_stdp91.be)',
#    'v(x1.x5.xno_stdp91.te)',
#    'v(x1.x5.xno_stdp92.be)',
#    'v(x1.x5.xno_stdp92.te)',
#    'v(x1.x5.xno_stdp93.be)',
#    'v(x1.x5.xno_stdp93.te)',
#    'v(x1.x5.xno_stdp94.be)',
#    'v(x1.x5.xno_stdp94.te)',
#    'v(x1.x5.xno_stdp95.be)',
#    'v(x1.x5.xno_stdp95.te)',
#    'v(x1.x5.xno_stdp96.be)',
#    'v(x1.x5.xno_stdp96.te)',
#    'v(x1.x5.xno_stdp97.be)',
#    'v(x1.x5.xno_stdp97.te)',
#    'v(x1.x5.xno_stdp98.be)',
#    'v(x1.x5.xno_stdp98.te)',
#    'v(x1.x5.xno_stdp99.be)',
#    'v(x1.x5.xno_stdp99.te)',
#    'v(x1.x5.xno_stdp100.be)',
#    'v(x1.x5.xno_stdp100.te)',
#    'v(x1.x5.xno_stdp101.be)',
#    'v(x1.x5.xno_stdp101.te)',
#    'v(x1.x5.xno_stdp102.be)',
#    'v(x1.x5.xno_stdp102.te)',
#    'v(x1.x5.xno_stdp103.be)',
#    'v(x1.x5.xno_stdp103.te)',
#    'v(x1.x5.xno_stdp104.be)',
#    'v(x1.x5.xno_stdp104.te)',
#    'v(x1.x5.xno_stdp105.be)',
#    'v(x1.x5.xno_stdp105.te)',
#    'v(x1.x5.xno_stdp106.be)',
#    'v(x1.x5.xno_stdp106.te)',
#    'v(x1.x5.xno_stdp107.be)',
#    'v(x1.x5.xno_stdp107.te)',
#    'v(x1.x5.xno_stdp108.be)',
#    'v(x1.x5.xno_stdp108.te)',
#    'v(x1.x5.xno_stdp109.be)',
#    'v(x1.x5.xno_stdp109.te)',
#    'v(x1.x5.xno_stdp110.be)',
#    'v(x1.x5.xno_stdp110.te)',
#    'v(x1.x5.xno_stdp111.be)',
#    'v(x1.x5.xno_stdp111.te)',
#    'v(x1.x5.xno_stdp112.be)',
#    'v(x1.x5.xno_stdp112.te)',
#    'v(x1.x5.xno_stdp113.be)',
#    'v(x1.x5.xno_stdp113.te)',
#    'v(x1.x5.xno_stdp114.be)',
#    'v(x1.x5.xno_stdp114.te)',
#    'v(x1.x5.xno_stdp115.be)',
#    'v(x1.x5.xno_stdp115.te)',
#    'v(x1.x5.xno_stdp116.be)',
#    'v(x1.x5.xno_stdp116.te)',
#    'v(x1.x5.xno_stdp117.be)',
#    'v(x1.x5.xno_stdp117.te)',
#    'v(x1.x5.xno_stdp118.be)',
#    'v(x1.x5.xno_stdp118.te)',
#    'v(x1.x5.xno_stdp119.be)',
#    'v(x1.x5.xno_stdp119.te)',
#    'v(x1.x5.xno_stdp120.be)',
#    'v(x1.x5.xno_stdp120.te)',
#    'v(x1.x5.xno_stdp121.be)',
#    'v(x1.x5.xno_stdp121.te)',
#    'v(x1.x5.xno_stdp122.be)',
#    'v(x1.x5.xno_stdp122.te)',
#    'v(x1.x5.xno_stdp123.be)',
#    'v(x1.x5.xno_stdp123.te)',
#    'v(x1.x5.xno_stdp124.be)',
#    'v(x1.x5.xno_stdp124.te)',
#    'v(x1.x5.xno_stdp125.be)',
#    'v(x1.x5.xno_stdp125.te)',
#    'v(x1.x5.xno_stdp126.be)',
#    'v(x1.x5.xno_stdp126.te)',
#    'v(x1.x5.xno_stdp127.be)',
#    'v(x1.x5.xno_stdp127.te)',
#    'v(x1.x5.xno_stdp128.be)',
#    'v(x1.x5.xno_stdp128.te)',
#    'v(x1.x7.xstdp1.be)',
#    'v(x1.x7.xstdp1.te)',
#    'v(x1.x7.xstdp2.be)',
#    'v(x1.x7.xstdp2.te)',
#    'v(x1.x7.xstdp3.be)',
#    'v(x1.x7.xstdp3.te)',
#    'v(x1.x7.xstdp4.be)',
#    'v(x1.x7.xstdp4.te)',
#    'v(x1.x7.xstdp5.be)',
#    'v(x1.x7.xstdp5.te)',
#    'v(x1.x7.xstdp6.be)',
#    'v(x1.x7.xstdp6.te)',
#    'v(x1.x7.xstdp7.be)',
#    'v(x1.x7.xstdp7.te)',
#    'v(x1.x7.xstdp8.be)',
#    'v(x1.x7.xstdp8.te)',
#    'v(x1.x7.xstdp9.be)',
#    'v(x1.x7.xstdp9.te)',
#    'v(x1.x7.xstdp10.be)',
#    'v(x1.x7.xstdp10.te)',
#    'v(x1.x7.xstdp11.be)',
#    'v(x1.x7.xstdp11.te)',
#    'v(x1.x7.xstdp12.be)',
#    'v(x1.x7.xstdp12.te)',
#    'v(x1.x7.xstdp13.be)',
#    'v(x1.x7.xstdp13.te)',
#    'v(x1.x7.xstdp14.be)',
#    'v(x1.x7.xstdp14.te)',
#    'v(x1.x7.xstdp15.be)',
#    'v(x1.x7.xstdp15.te)',
#    'v(x1.x7.xstdp16.be)',
#    'v(x1.x7.xstdp16.te)',
#    'v(x1.x7.xstdp17.be)',
#    'v(x1.x7.xstdp17.te)',
#    'v(x1.x7.xstdp18.be)',
#    'v(x1.x7.xstdp18.te)',
#    'v(x1.x7.xstdp19.be)',
#    'v(x1.x7.xstdp19.te)',
#    'v(x1.x7.xstdp20.be)',
#    'v(x1.x7.xstdp20.te)',
#    'v(x1.x7.xstdp21.be)',
#    'v(x1.x7.xstdp21.te)',
#    'v(x1.x7.xstdp22.be)',
#    'v(x1.x7.xstdp22.te)',
#    'v(x1.x7.xstdp23.be)',
#    'v(x1.x7.xstdp23.te)',
#    'v(x1.x7.xstdp24.be)',
#    'v(x1.x7.xstdp24.te)',
#    'v(x1.x7.xstdp25.be)',
#    'v(x1.x7.xstdp25.te)',
#    'v(x1.x7.xstdp26.be)',
#    'v(x1.x7.xstdp26.te)',
#    'v(x1.x7.xstdp27.be)',
#    'v(x1.x7.xstdp27.te)',
#    'v(x1.x7.xstdp28.be)',
#    'v(x1.x7.xstdp28.te)',
#    'v(x1.x7.xstdp29.be)',
#    'v(x1.x7.xstdp29.te)',
#    'v(x1.x7.xstdp30.be)',
#    'v(x1.x7.xstdp30.te)',
#    'v(x1.x7.xstdp31.be)',
#    'v(x1.x7.xstdp31.te)',
#    'v(x1.x7.xstdp32.be)',
#    'v(x1.x7.xstdp32.te)',
#    'v(x_nom)',
#    'v(x_ref)'],
#   'varunits': ['time',
#    'voltage',
#    'voltage',
#    'voltage',
#    'voltage',
#    'voltage',
#    'voltage',
#    'voltage',
#    'voltage',
#    'voltage',
#    'voltage',
#    'voltage',
#    'current',
#    'current',
#    'current',
#    'current',
#    'current',
#    'current',
#    'current',
#    'current',
#    'current',
#    'current',
#    'current',
#    'current',
#    'current',
#    'current',
#    'current',
#    'current',
#    'current',
#    'current',
#    'current',
#    'current',
#    'current',
#    'current',
#    'current',
#    'current',
#    'current',
#    'current',
#    'current',
#    'current',
#    'current',
#    'current',
#    'current',
#    'current',
#    'current',
#    'current',
#    'current',
#    'current',
#    'current',
#    'current',
#    'current',
#    'current',
#    'current',
#    'current',
#    'current',
#    'current',
#    'current',
#    'current',
#    'current',
#    'current',
#    'current',
#    'current',
#    'current',
#    'current',
#    'current',
#    'current',
#    'current',
#    'current',
#    'current',
#    'current',
#    'current',
#    'current',
#    'current',
#    'current',
#    'current',
#    'current',
#    'current',
#    'current',
#    'current',
#    'current',
#    'current',
#    'current',
#    'current',
#    'current',
#    'current',
#    'current',
#    'current',
#    'current',
#    'current',
#    'current',
#    'current',
#    'current',
#    'current',
#    'current',
#    'current',
#    'current',
#    'current',
#    'current',
#    'current',
#    'current',
#    'current',
#    'current',
#    'current',
#    'current',
#    'current',
#    'current',
#    'current',
#    'current',
#    'current',
#    'current',
#    'current',
#    'current',
#    'current',
#    'current',
#    'current',
#    'current',
#    'current',
#    'current',
#    'current',
#    'current',
#    'current',
#    'current',
#    'current',
#    'current',
#    'current',
#    'current',
#    'current',
#    'current',
#    'current',
#    'current',
#    'current',
#    'current',
#    'current',
#    'current',
#    'current',
#    'current',
#    'current',
#    'current',
#    'current',
#    'current',
#    'current',
#    'current',
#    'current',
#    'current',
#    'current',
#    'current',
#    'current',
#    'current',
#    'current',
#    'current',
#    'current',
#    'current',
#    'current',
#    'current',
#    'current',
#    'current',
#    'current',
#    'current',
#    'current',
#    'current',
#    'current',
#    'current',
#    'current',
#    'current',
#    'current',
#    'current',
#    'current',
#    'current',
#    'current',
#    'current',
#    'current',
#    'current',
#    'current',
#    'current',
#    'current',
#    'current',
#    'current',
#    'current',
#    'current',
#    'current',
#    'current',
#    'current',
#    'current',
#    'current',
#    'current',
#    'current',
#    'current',
#    'current',
#    'voltage',
#    'voltage',
#    'voltage',
#    'voltage',
#    'voltage',
#    'voltage',
#    'voltage',
#    'voltage',
#    'voltage',
#    'voltage',
#    'voltage',
#    'voltage',
#    'voltage',
#    'voltage',
#    'voltage',
#    'voltage',
#    'voltage',
#    'voltage',
#    'voltage',
#    'voltage',
#    'voltage',
#    'voltage',
#    'voltage',
#    'voltage',
#    'voltage',
#    'voltage',
#    'voltage',
#    'voltage',
#    'voltage',
#    'voltage',
#    'voltage',
#    'voltage',
#    'voltage',
#    'voltage',
#    'voltage',
#    'voltage',
#    'voltage',
#    'voltage',
#    'voltage',
#    'voltage',
#    'voltage',
#    'voltage',
#    'voltage',
#    'voltage',
#    'voltage',
#    'voltage',
#    'voltage',
#    'voltage',
#    'voltage',
#    'voltage',
#    'voltage',
#    'voltage',
#    'voltage',
#    'voltage',
#    'voltage',
#    'voltage',
#    'voltage',
#    'voltage',
#    'voltage',
#    'voltage',
#    'voltage',
#    'voltage',
#    'voltage',
#    'voltage',
#    'voltage',
#    'voltage',
#    'voltage',
#    'voltage',
#    'voltage',
#    'voltage',
#    'voltage',
#    'voltage',
#    'voltage',
#    'voltage',
#    'voltage',
#    'voltage',
#    'voltage',
#    'voltage',
#    'voltage',
#    'voltage',
#    'voltage',
#    'voltage',
#    'voltage',
#    'voltage',
#    'voltage',
#    'voltage',
#    'voltage',
#    'voltage',
#    'voltage',
#    'voltage',
#    'voltage',
#    'voltage',
#    'voltage',
#    'voltage',
#    'voltage',
#    'voltage',
#    'voltage',
#    'voltage',
#    'voltage',
#    'voltage',
#    'voltage',
#    'voltage',
#    'voltage',
#    'voltage',
#    'voltage',
#    'voltage',
#    'voltage',
#    'voltage',
#    'voltage',
#    'voltage',
#    'voltage',
#    'voltage',
#    'voltage',
#    'voltage',
#    'voltage',
#    'voltage',
#    'voltage',
#    'voltage',
#    'voltage',
#    'voltage',
#    'voltage',
#    'voltage',
#    'voltage',
#    'voltage',
#    'voltage',
#    'voltage',
#    'voltage',
#    'voltage',
#    'voltage',
#    'voltage',
#    'voltage',
#    'voltage',
#    'voltage',
#    'voltage',
#    'voltage',
#    'voltage',
#    'voltage',
#    'voltage',
#    'voltage',
#    'voltage',
#    'voltage',
#    'voltage',
#    'voltage',
#    'voltage',
#    'voltage',
#    'voltage',
#    'voltage',
#    'voltage',
#    'voltage',
#    'voltage',
#    'voltage',
#    'voltage',
#    'voltage',
#    'voltage',
#    'voltage',
#    'voltage',
#    'voltage',
#    'voltage',
#    'voltage',
#    'voltage',
#    'voltage',
#    'voltage',
#    'voltage',
#    'voltage',
#    'voltage',
#    'voltage',
#    'voltage',
#    'voltage',
#    'voltage',
#    'voltage',
#    'voltage',
#    'voltage',
#    'voltage',
#    'voltage',
#    'voltage',
#    'voltage',
#    'voltage',
#    'voltage',
#    'voltage',
#    'voltage',
#    'voltage',
#    'voltage',
#    'voltage',
#    'voltage',
#    'voltage',
#    'voltage',
#    'voltage',
#    'voltage',
#    'voltage',
#    'voltage',
#    'voltage',
#    'voltage',
#    'voltage',
#    'voltage',
#    'voltage',
#    'voltage',
#    'voltage',
#    'voltage',
#    'voltage',
#    'voltage',
#    'voltage',
#    'voltage',
#    'voltage',
#    'voltage',
#    'voltage',
#    'voltage',
#    'voltage',
#    'voltage',
#    'voltage',
#    'voltage',
#    'voltage',
#    'voltage',
#    'voltage',
#    'voltage',
#    'voltage',
#    'voltage',
#    'voltage',
#    'voltage',
#    'voltage',
#    'voltage',
#    'voltage',
#    'voltage',
#    'voltage',
#    'voltage',
#    'voltage',
#    'voltage',
#    'voltage',
#    'voltage',
#    'voltage',
#    'voltage',
#    'voltage',
#    'voltage',
#    'voltage',
#    'voltage',
#    'voltage',
#    'voltage',
#    'voltage',
#    'voltage',
#    'voltage',
#    'voltage',
#    'voltage',
#    'voltage',
#    'voltage',
#    'voltage',
#    'voltage',
#    'voltage',
#    'voltage',
#    'voltage',
#    'voltage',
#    'voltage',
#    'voltage',
#    'voltage',
#    'voltage',
#    'voltage',
#    'voltage',
#    'voltage',
#    'voltage',
#    'voltage',
#    'voltage',
#    'voltage',
#    'voltage',
#    'voltage',
#    'voltage',
#    'voltage',
#    'voltage',
#    'voltage',
#    'voltage',
#    'voltage',
#    'voltage',
#    'voltage',
#    'voltage',
#    'voltage',
#    'voltage',
#    'voltage',
#    'voltage',
#    'voltage',
#    'voltage',
#    'voltage',
#    'voltage',
#    'voltage',
#    'voltage',
#    'voltage',
#    'voltage',
#    'voltage',
#    'voltage',
#    'voltage',
#    'voltage',
#    'voltage',
#    'voltage',
#    'voltage',
#    'voltage',
#    'voltage',
#    'voltage',
#    'voltage',
#    'voltage',
#    'voltage',
#    'voltage',
#    'voltage',
#    'voltage',
#    'voltage',
#    'voltage',
#    'voltage',
#    'voltage',
#    'voltage',
#    'voltage',
#    'voltage',
#    'voltage',
#    'voltage',
#    'voltage',
#    'voltage',
#    'voltage',
#    'voltage',
#    'voltage',
#    'voltage',
#    'voltage',
#    'voltage',
#    'voltage',
#    'voltage',
#    'voltage',
#    'voltage',
#    'voltage',
#    'voltage',
#    'voltage',
#    'voltage',
#    'voltage',
#    'voltage',
#    'voltage',
#    'voltage',
#    'voltage']}]

# %%
fig, [ax0, ax1, ax2] = plt.subplots(3, figsize=(10,5))
ax0.plot(data["time"][::intp], data["v(tau)"][::intp], label = f"tau")
ax0.legend()
ax0.grid()
ax0.set_xlabel("Time [ms]")
ax0.set_ylabel("tau[V]")

ax1.plot(data["time"][::intp], data["v(x)"][::intp], label = f"x")
ax1.plot(data["time"][::intp], data["v(dx)"][::intp], label = f"dx")
ax1.legend()
ax1.grid()
ax1.set_xlabel("Time [ms]")
ax1.set_ylabel("x and dx[V]")
ax2.plot(data["time"][::intp], data["v(th)"][::intp], label = f"th")
ax2.plot(data["time"][::intp], data["v(dth)"][::intp], label = f"dth")
ax2.legend()
ax2.grid()
ax2.set_xlabel("Time [ms]")
ax2.set_ylabel("th and dth[V]")
fig.suptitle("mwip inputs and outputs")
plt.tight_layout(rect=[0, 0.03, 1, 0.95])

# %%
fig, [ax0, ax1, ax2] = plt.subplots(3, figsize=(10,5))
ax0.plot(data["time"][::intp], data["v(tau_nom)"][::intp], label = f"tau_nom")
ax0.legend()
ax0.grid()
ax0.set_xlabel("Time [ms]")
ax0.set_ylabel("tau[V]")

ax1.plot(data["time"][::intp], data["v(x_nom)"][::intp], label = f"x_nom")
ax1.plot(data["time"][::intp], data["v(dx_nom)"][::intp], label = f"dx_nom")
ax1.legend()
ax1.grid()
ax1.set_xlabel("Time [ms]")
ax1.set_ylabel("x and dx[V]")
ax2.plot(data["time"][::intp], data["v(th_nom)"][::intp], label = f"th_nom")
ax2.plot(data["time"][::intp], data["v(dth_nom)"][::intp], label = f"dth_nom")
ax2.legend()
ax2.grid()
ax2.set_xlabel("Time [ms]")
ax2.set_ylabel("th and dth[V]")
fig.suptitle("Normalized mwip inputs and outputs")
plt.tight_layout(rect=[0, 0.03, 1, 0.95])

# %%
fig, (ax1, ax2, ax3) = plt.subplots(3, figsize=(10,10))
for k in range(4):
    nodo = "v(x1.hj" +  str(k+1) + ")"
    ax1.plot(data["time"][::intp], data[nodo][::intp]+(1.8*k), label = f"hj{k+1}")
    # frec_k = obtainFrequencies(data["time"][::intp], data[nodo][::intp])
    # ax1.plot(data["time"][::intp], frec_k, label = f"N{k+1}")

ax1.legend()
ax1.grid()
ax1.set_xlabel("Time [ms]")
ax1.set_ylabel("Spikes [V]")
ax1.set_title("Input Layer Neural activity")

ax2.plot(data["time"][::intp], data["v(x1.hk1)"][::intp], label = f"hk1")
ax2.legend()
ax2.grid()
ax2.set_xlabel("Time [ms]")
ax2.set_ylabel("Spikes [V]")
ax2.set_title("hidden Layer Neural activity")


ax3.plot(data["time"][::intp], data["v(x1.hl1)"][::intp], label = f"hL1")
ax3.legend()
ax3.grid()
ax3.set_xlabel("Time [ms]")
ax3.set_ylabel("Spikes [V]")
ax3.set_title("Input Layer Neural activity")

plt.tight_layout(rect=[0, 0.03, 1, 0.95])
# fig.savefig('InputLayer.pdf')

# %%
fig, [ax1, ax2] = plt.subplots(2, figsize=(10,10))
for k in range(8):
    nodo = "v(j" +  str(k+1) + ")"
    ax1.plot(data["time"][::intp], data[nodo][::intp]+(1.8*k), label = f"J{k+1}")
ax1.legend()
ax1.grid()
ax1.set_xlabel("Time [ms]")
ax1.set_ylabel("Spikes [V]")
ax1.set_title("Hidden Layer Neural activity")


for k in range(8):
    Iext_label = "i(v.x4.xx" + str(k+1)+ ".vext)"
    ax2.plot(data["time"][::intp], data[Iext_label][::intp], label = f"i{k+1}")

ax2.grid()
ax2.set_xlabel("Time [ms]")
ax2.set_ylabel("Input Currrent[Amp]")
ax2.set_title("Input Current Hidden Layer")
ax2.set_ylim((0, 5e-7))
# fig.savefig('HiddenLayer.pdf')

# %%
fig, [ax1, ax2] = plt.subplots(2, figsize=(10,10))
for k in range(4):
    nodo = "v(m" +  str(k+1) + ")"
    ax1.plot(data["time"][::intp], data[nodo][::intp]+(1.8*k), label = f"M{k+1}")
ax1.legend()
ax1.grid()
ax1.set_xlabel("Time [ms]")
ax1.set_ylabel("Spikes [V]")
ax1.set_title("Output Layer Neural activity")

for k in range(4):
    Iext_label = "i(v.x2.xx" + str(k+1)+ ".vext)"
    ax2.plot(data["time"][::intp], data[Iext_label][::intp], label = f"i{k+1}")

ax2.grid()
ax2.set_xlabel("Time [ms]")
ax2.set_ylabel("Input Currrent[Amp]")
ax2.set_title("Input Current Output Layer")
ax2.set_ylim((1e-7, 1.6e-7))

# fig.savefig('OutputLayer.pdf')

# %%
plt.plot(data["time"][::intp], data["v(in)"][::intp], label = "in")

# %%
fig, [ax1, ax2, ax3] = plt.subplots(3, figsize=(8,12))

ax1.plot(data["time"][::intp], data["v(hx)"][::intp], label = "hx")
ax1.plot(data["time"][::intp], data["v(x)"][::intp], label = "x")
ax1.legend()
ax1.grid()
ax1.set_xlabel("Time [ms]")
ax1.set_ylabel("Voltage [V]")
ax1.set_title("Voltage signals")


ax2.plot(data["time"][::intp], data["v(hx)"][::intp] - data["v(x)"][::intp], label = "error")
ax2.legend()
ax2.grid()
ax2.set_xlabel("Time [ms]")
ax2.set_ylabel("Voltage [V]")
ax2.set_title("Error")

ax3.plot(data["time"][::intp], data["v(vr1)"][::intp], label = "Vr1")
ax3.set_xlabel("Time [ms]")
ax3.set_ylabel("Voltage [V]")
ax3.set_title("Reward Signal")
ax3.grid()
# fig.savefig('Signals.pdf')

# %%
mem_ij = []
fig, [ax1, ax2] = plt.subplots(2, figsize=(10,15))
for k in range(32):
    Imem_label = "i(v.x5.xno_stdp" +  str(k+1) + ".vmr)"
    Vte_label = "v(x5.xno_stdp" +  str(k+1) + ".te)"
    Vbe_label = "v(x5.xno_stdp" +  str(k+1) + ".be)"
    Imem= data[Imem_label][::intp]
    Vte = data[Vte_label][::intp]
    Vbe = data[Vbe_label][::intp]
    mem = (Vbe -  Vte)/Imem 
    ax1.plot(data["time"][::intp], mem,".", label = f"ij{k+1}", linewidth=1, markersize=2)
    mem_ij.append(mem)
    
# ax.legend()
ax1.grid()
ax1.set_xlabel("Time [ms]")
ax1.set_ylabel("Memristance [Ohms]")
ax1.set_title("Memristance value ij")
ax1.set_ylim((-0.2e6, 3.5e6))

mem_jk = []
for k in range(32):
    Imem_label = "i(v.x6.xstdp" +  str(k+1) + ".vmr)"
    Vte_label =  "v(x6.xstdp" +  str(k+1) + ".te)"
    Vbe_label = "v(x6.xstdp" +  str(k+1) + ".be)"
    Imem= data[Imem_label][::intp]
    Vte = data[Vte_label][::intp]
    Vbe = data[Vbe_label][::intp]
    mem = (Vbe - Vte)/Imem 
    ax2.plot(data["time"][::intp], mem,".", label = f"jk{k+1}",linewidth=1, markersize=2)
    mem_jk.append(mem)


# ax.legend()
ax2.grid()
ax2.set_xlabel("Time [ms]")
ax2.set_ylabel("Memristance [Ohms]")
ax2.set_title("Memristance value jk")
ax2.set_ylim((-0.2e6, 3.5e6))
# fig.savefig('weights.pdf')
